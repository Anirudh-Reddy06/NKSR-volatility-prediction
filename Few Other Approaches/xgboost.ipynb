# %%
import pandas as pd
import numpy as np
from sklearn.experimental import enable_iterative_imputer
from sklearn.impute import IterativeImputer
from xgboost import XGBRegressor
import warnings
warnings.filterwarnings('ignore')

# Load your data
test = pd.read_parquet('test_data.parquet')
sample_submission = pd.read_csv('sample_submission.csv')

# Identify target columns (excluding 'timestamp')
target_columns = [col for col in sample_submission.columns if col != 'timestamp']
submission = sample_submission.copy()
for col in target_columns:
    submission[col] = test[col] if col in test.columns else np.nan

# Optionally include 'underlying' if present
if 'underlying' in test.columns:
    submission['underlying'] = test['underlying']
    all_imputation_cols = target_columns + ['underlying']
else:
    all_imputation_cols = target_columns

# Setup XGBoost imputer
imputer_xgb = IterativeImputer(
    estimator=XGBRegressor(
        n_estimators=200,
        max_depth=10,
        learning_rate=0.07,
        subsample=0.8,
        colsample_bytree=0.8,
        tree_method='hist',
        random_state=42,
        verbosity=0
    ),
    max_iter=50,
    tol=1e-6,
    n_nearest_features=20,
    initial_strategy='median',
    imputation_order='ascending',
    random_state=42,
    verbose=2
)

# Fit imputer on the submission data
imputer_xgb.fit(submission[all_imputation_cols])

# Transform to get imputed values
imputed_xgb = imputer_xgb.transform(submission[all_imputation_cols])

# Prepare output dataframe
xgb_pred = submission.copy()
xgb_pred[target_columns] = imputed_xgb[:, :len(target_columns)]

# Save to CSV
xgb_pred.to_csv('xgb_imputation.csv', index=False)
print("XGBoost imputation predictions saved to 'xgb_predictions.csv'.")
# Out:
# [IterativeImputer] Completing matrix with shape (12065, 53)
# [IterativeImputer] Ending imputation round 1/50, elapsed time 24.26
# [IterativeImputer] Change: 2.5996083081703185, scaled tolerance: 0.0250595
# [IterativeImputer] Ending imputation round 2/50, elapsed time 52.21
# [IterativeImputer] Change: 0.32498234510421753, scaled tolerance: 0.0250595
# [IterativeImputer] Ending imputation round 3/50, elapsed time 72.16
# [IterativeImputer] Change: 0.1609470695257187, scaled tolerance: 0.0250595
# [IterativeImputer] Ending imputation round 4/50, elapsed time 87.42
# [IterativeImputer] Change: 0.14960743486881256, scaled tolerance: 0.0250595
# [IterativeImputer] Ending imputation round 5/50, elapsed time 102.70
# [IterativeImputer] Change: 0.1466507464647293, scaled tolerance: 0.0250595
# [IterativeImputer] Ending imputation round 6/50, elapsed time 117.38
# [IterativeImputer] Change: 0.18262746930122375, scaled tolerance: 0.0250595
# [IterativeImputer] Ending imputation round 7/50, elapsed time 132.61
# [IterativeImputer] Change: 0.14603222906589508, scaled tolerance: 0.0250595
# [IterativeImputer] Ending imputation round 8/50, elapsed time 147.80
# [IterativeImputer] Change: 0.13289713859558105, scaled tolerance: 0.0250595
# [IterativeImputer] Ending imputation round 9/50, elapsed time 163.11
# [IterativeImputer] Change: 0.13547246158123016, scaled tolerance: 0.0250595
# [IterativeImputer] Ending imputation round 10/50, elapsed time 178.09
# [IterativeImputer] Change: 0.12990102171897888, scaled tolerance: 0.0250595
# [IterativeImputer] Ending imputation round 11/50, elapsed time 193.94
# [IterativeImputer] Change: 0.12432007491588593, scaled tolerance: 0.0250595
# [IterativeImputer] Ending imputation round 12/50, elapsed time 209.02
# [IterativeImputer] Change: 0.1159587949514389, scaled tolerance: 0.0250595
# [IterativeImputer] Ending imputation round 13/50, elapsed time 224.28
# [IterativeImputer] Change: 0.09729734063148499, scaled tolerance: 0.0250595
# [IterativeImputer] Ending imputation round 14/50, elapsed time 239.47
# [IterativeImputer] Change: 0.1029377430677414, scaled tolerance: 0.0250595
# [IterativeImputer] Ending imputation round 15/50, elapsed time 255.29
# [IterativeImputer] Change: 0.08288964629173279, scaled tolerance: 0.0250595
# [IterativeImputer] Ending imputation round 16/50, elapsed time 271.03
# [IterativeImputer] Change: 0.1769685298204422, scaled tolerance: 0.0250595
# [IterativeImputer] Ending imputation round 17/50, elapsed time 289.11
# [IterativeImputer] Change: 0.12616577744483948, scaled tolerance: 0.0250595
# [IterativeImputer] Ending imputation round 18/50, elapsed time 304.92
# [IterativeImputer] Change: 0.16868941485881805, scaled tolerance: 0.0250595
# [IterativeImputer] Ending imputation round 19/50, elapsed time 320.22
# [IterativeImputer] Change: 0.11465547978878021, scaled tolerance: 0.0250595
# [IterativeImputer] Ending imputation round 20/50, elapsed time 335.46
# [IterativeImputer] Change: 0.1262834221124649, scaled tolerance: 0.0250595
# [IterativeImputer] Ending imputation round 21/50, elapsed time 353.08
# [IterativeImputer] Change: 0.10998532176017761, scaled tolerance: 0.0250595
# [IterativeImputer] Ending imputation round 22/50, elapsed time 371.75
# [IterativeImputer] Change: 0.11390803754329681, scaled tolerance: 0.0250595
# [IterativeImputer] Ending imputation round 23/50, elapsed time 387.18
# [IterativeImputer] Change: 0.13764211535453796, scaled tolerance: 0.0250595
# [IterativeImputer] Ending imputation round 24/50, elapsed time 403.67
# [IterativeImputer] Change: 0.15266628563404083, scaled tolerance: 0.0250595
# [IterativeImputer] Ending imputation round 25/50, elapsed time 419.91
# [IterativeImputer] Change: 0.1178971379995346, scaled tolerance: 0.0250595
# [IterativeImputer] Ending imputation round 26/50, elapsed time 439.25
# [IterativeImputer] Change: 0.08870254456996918, scaled tolerance: 0.0250595
# [IterativeImputer] Ending imputation round 27/50, elapsed time 455.06
# [IterativeImputer] Change: 0.06838321685791016, scaled tolerance: 0.0250595
# [IterativeImputer] Ending imputation round 28/50, elapsed time 470.64
# [IterativeImputer] Change: 0.10366152226924896, scaled tolerance: 0.0250595
# [IterativeImputer] Ending imputation round 29/50, elapsed time 486.56
# [IterativeImputer] Change: 0.10807028412818909, scaled tolerance: 0.0250595
# [IterativeImputer] Ending imputation round 30/50, elapsed time 503.59
# [IterativeImputer] Change: 0.11615490913391113, scaled tolerance: 0.0250595
# [IterativeImputer] Ending imputation round 31/50, elapsed time 519.68
# [IterativeImputer] Change: 0.16632363200187683, scaled tolerance: 0.0250595
# [IterativeImputer] Ending imputation round 32/50, elapsed time 534.81
# [IterativeImputer] Change: 0.15690378844738007, scaled tolerance: 0.0250595
# [IterativeImputer] Ending imputation round 33/50, elapsed time 550.69
# [IterativeImputer] Change: 0.13052284717559814, scaled tolerance: 0.0250595
# [IterativeImputer] Ending imputation round 34/50, elapsed time 566.02
# [IterativeImputer] Change: 0.10373157262802124, scaled tolerance: 0.0250595
# [IterativeImputer] Ending imputation round 35/50, elapsed time 581.60
# [IterativeImputer] Change: 0.08568055927753448, scaled tolerance: 0.0250595
# [IterativeImputer] Ending imputation round 36/50, elapsed time 597.28
# [IterativeImputer] Change: 0.100009024143219, scaled tolerance: 0.0250595
# [IterativeImputer] Ending imputation round 37/50, elapsed time 613.77
# [IterativeImputer] Change: 0.13106279075145721, scaled tolerance: 0.0250595
# [IterativeImputer] Ending imputation round 38/50, elapsed time 630.33
# [IterativeImputer] Change: 0.1116173267364502, scaled tolerance: 0.0250595
# [IterativeImputer] Ending imputation round 39/50, elapsed time 646.30
# [IterativeImputer] Change: 0.13654223084449768, scaled tolerance: 0.0250595
# [IterativeImputer] Ending imputation round 40/50, elapsed time 662.66
# [IterativeImputer] Change: 0.13934795558452606, scaled tolerance: 0.0250595
# [IterativeImputer] Ending imputation round 41/50, elapsed time 680.88
# [IterativeImputer] Change: 0.1354500651359558, scaled tolerance: 0.0250595
# [IterativeImputer] Ending imputation round 42/50, elapsed time 696.84
# [IterativeImputer] Change: 0.1108311265707016, scaled tolerance: 0.0250595
# [IterativeImputer] Ending imputation round 43/50, elapsed time 713.02
# [IterativeImputer] Change: 0.1638692319393158, scaled tolerance: 0.0250595
# [IterativeImputer] Ending imputation round 44/50, elapsed time 729.05
# [IterativeImputer] Change: 0.19852571189403534, scaled tolerance: 0.0250595
# [IterativeImputer] Ending imputation round 45/50, elapsed time 744.84
# [IterativeImputer] Change: 0.12822352349758148, scaled tolerance: 0.0250595
# [IterativeImputer] Ending imputation round 46/50, elapsed time 760.98
# [IterativeImputer] Change: 0.09173561632633209, scaled tolerance: 0.0250595
# [IterativeImputer] Ending imputation round 47/50, elapsed time 776.93
# [IterativeImputer] Change: 0.10850712656974792, scaled tolerance: 0.0250595
# [IterativeImputer] Ending imputation round 48/50, elapsed time 793.72
# [IterativeImputer] Change: 0.1180688738822937, scaled tolerance: 0.0250595
# [IterativeImputer] Ending imputation round 49/50, elapsed time 809.34
# [IterativeImputer] Change: 0.1221340000629425, scaled tolerance: 0.0250595
# [IterativeImputer] Ending imputation round 50/50, elapsed time 825.01
# [IterativeImputer] Change: 0.08687491714954376, scaled tolerance: 0.0250595
# [IterativeImputer] Completing matrix with shape (12065, 53)
# [IterativeImputer] Ending imputation round 1/50, elapsed time 0.38
# [IterativeImputer] Ending imputation round 2/50, elapsed time 0.65
# [IterativeImputer] Ending imputation round 3/50, elapsed time 0.92
# [IterativeImputer] Ending imputation round 4/50, elapsed time 1.21
# [IterativeImputer] Ending imputation round 5/50, elapsed time 1.49
# [IterativeImputer] Ending imputation round 6/50, elapsed time 1.75
# [IterativeImputer] Ending imputation round 7/50, elapsed time 2.04
# [IterativeImputer] Ending imputation round 8/50, elapsed time 2.33
# [IterativeImputer] Ending imputation round 9/50, elapsed time 2.66
# [IterativeImputer] Ending imputation round 10/50, elapsed time 2.92
# [IterativeImputer] Ending imputation round 11/50, elapsed time 3.21
# [IterativeImputer] Ending imputation round 12/50, elapsed time 3.51
# [IterativeImputer] Ending imputation round 13/50, elapsed time 3.79
# [IterativeImputer] Ending imputation round 14/50, elapsed time 4.07
# [IterativeImputer] Ending imputation round 15/50, elapsed time 4.37
# [IterativeImputer] Ending imputation round 16/50, elapsed time 4.65
# [IterativeImputer] Ending imputation round 17/50, elapsed time 4.93
# [IterativeImputer] Ending imputation round 18/50, elapsed time 5.23
# [IterativeImputer] Ending imputation round 19/50, elapsed time 5.52
# [IterativeImputer] Ending imputation round 20/50, elapsed time 5.79
# [IterativeImputer] Ending imputation round 21/50, elapsed time 6.06
# [IterativeImputer] Ending imputation round 22/50, elapsed time 6.36
# [IterativeImputer] Ending imputation round 23/50, elapsed time 6.64
# [IterativeImputer] Ending imputation round 24/50, elapsed time 6.97
# [IterativeImputer] Ending imputation round 25/50, elapsed time 7.28
# [IterativeImputer] Ending imputation round 26/50, elapsed time 7.58
# [IterativeImputer] Ending imputation round 27/50, elapsed time 7.86
# [IterativeImputer] Ending imputation round 28/50, elapsed time 8.15
# [IterativeImputer] Ending imputation round 29/50, elapsed time 8.43
# [IterativeImputer] Ending imputation round 30/50, elapsed time 8.72
# [IterativeImputer] Ending imputation round 31/50, elapsed time 9.00
# [IterativeImputer] Ending imputation round 32/50, elapsed time 9.29
# [IterativeImputer] Ending imputation round 33/50, elapsed time 9.58
# [IterativeImputer] Ending imputation round 34/50, elapsed time 9.86
# [IterativeImputer] Ending imputation round 35/50, elapsed time 10.16
# [IterativeImputer] Ending imputation round 36/50, elapsed time 10.43
# [IterativeImputer] Ending imputation round 37/50, elapsed time 10.72
# [IterativeImputer] Ending imputation round 38/50, elapsed time 11.04
# [IterativeImputer] Ending imputation round 39/50, elapsed time 11.33
# [IterativeImputer] Ending imputation round 40/50, elapsed time 11.61
# [IterativeImputer] Ending imputation round 41/50, elapsed time 11.89
# [IterativeImputer] Ending imputation round 42/50, elapsed time 12.19
# [IterativeImputer] Ending imputation round 43/50, elapsed time 12.46
# [IterativeImputer] Ending imputation round 44/50, elapsed time 12.74
# [IterativeImputer] Ending imputation round 45/50, elapsed time 13.06
# [IterativeImputer] Ending imputation round 46/50, elapsed time 13.36
# [IterativeImputer] Ending imputation round 47/50, elapsed time 13.67
# [IterativeImputer] Ending imputation round 48/50, elapsed time 13.97
# [IterativeImputer] Ending imputation round 49/50, elapsed time 14.30
# [IterativeImputer] Ending imputation round 50/50, elapsed time 14.58
# XGBoost imputation predictions saved to 'xgb_predictions.csv'.
