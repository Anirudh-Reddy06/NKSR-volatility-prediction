# %%
import pandas as pd
import numpy as np
from sklearn.experimental import enable_iterative_imputer
from sklearn.impute import IterativeImputer
from sklearn.linear_model import Lasso
import warnings
warnings.filterwarnings('ignore')

# Load your actual data
test = pd.read_parquet('test_data.parquet')
sample_submission = pd.read_csv('sample_submission.csv')

# Identify target columns (excluding 'timestamp')
target_columns = [col for col in sample_submission.columns if col != 'timestamp']
submission = sample_submission.copy()
for col in target_columns:
    submission[col] = test[col] if col in test.columns else np.nan

# Optionally include 'underlying' if present
if 'underlying' in test.columns:
    submission['underlying'] = test['underlying']
    all_imputation_cols = target_columns + ['underlying']
else:
    all_imputation_cols = target_columns

# Setup Lasso imputer
imputer_lasso = IterativeImputer(
    estimator=Lasso(alpha=0.01, max_iter=2000, random_state=46),
    max_iter=50,
    tol=1e-6,
    n_nearest_features=20,
    initial_strategy='median',
    imputation_order='ascending',
    random_state=46,
    verbose=2
)

# Fit imputer on the submission data
imputer_lasso.fit(submission[all_imputation_cols])

# Transform to get imputed values
imputed_lasso = imputer_lasso.transform(submission[all_imputation_cols])

# Prepare output dataframe
lasso_pred = submission.copy()
lasso_pred[target_columns] = imputed_lasso[:, :len(target_columns)]

# Save to CSV for blending
lasso_pred.to_csv('lasso_imputation.csv', index=False)
print("Lasso imputation predictions saved to 'lasso_predictions.csv'.")
# Out:
# [IterativeImputer] Completing matrix with shape (12065, 53)
# [IterativeImputer] Ending imputation round 1/50, elapsed time 0.36
# [IterativeImputer] Change: 1.3812496172619133, scaled tolerance: 0.0250595
# [IterativeImputer] Ending imputation round 2/50, elapsed time 1.75
# [IterativeImputer] Change: 0.5568173098936476, scaled tolerance: 0.0250595
# [IterativeImputer] Ending imputation round 3/50, elapsed time 2.39
# [IterativeImputer] Change: 0.835723084401726, scaled tolerance: 0.0250595
# [IterativeImputer] Ending imputation round 4/50, elapsed time 3.95
# [IterativeImputer] Change: 1.0316502999353279, scaled tolerance: 0.0250595
# [IterativeImputer] Ending imputation round 5/50, elapsed time 4.86
# [IterativeImputer] Change: 1.073156618397394, scaled tolerance: 0.0250595
# [IterativeImputer] Ending imputation round 6/50, elapsed time 5.26
# [IterativeImputer] Change: 0.749597413939392, scaled tolerance: 0.0250595
# [IterativeImputer] Ending imputation round 7/50, elapsed time 5.80
# [IterativeImputer] Change: 0.849870570798738, scaled tolerance: 0.0250595
# [IterativeImputer] Ending imputation round 8/50, elapsed time 6.54
# [IterativeImputer] Change: 1.186072159515768, scaled tolerance: 0.0250595
# [IterativeImputer] Ending imputation round 9/50, elapsed time 7.71
# [IterativeImputer] Change: 0.95751186844935, scaled tolerance: 0.0250595
# [IterativeImputer] Ending imputation round 10/50, elapsed time 9.07
# [IterativeImputer] Change: 0.5057917432779032, scaled tolerance: 0.0250595
# [IterativeImputer] Ending imputation round 11/50, elapsed time 10.36
# [IterativeImputer] Change: 0.7135083192664358, scaled tolerance: 0.0250595
# [IterativeImputer] Ending imputation round 12/50, elapsed time 10.86
# [IterativeImputer] Change: 0.908903077139286, scaled tolerance: 0.0250595
# [IterativeImputer] Ending imputation round 13/50, elapsed time 12.50
# [IterativeImputer] Change: 0.7177308527509063, scaled tolerance: 0.0250595
# [IterativeImputer] Ending imputation round 14/50, elapsed time 13.59
# [IterativeImputer] Change: 1.050450467265631, scaled tolerance: 0.0250595
# [IterativeImputer] Ending imputation round 15/50, elapsed time 14.19
# [IterativeImputer] Change: 0.9369745803611581, scaled tolerance: 0.0250595
# [IterativeImputer] Ending imputation round 16/50, elapsed time 15.27
# [IterativeImputer] Change: 0.9463881615428772, scaled tolerance: 0.0250595
# [IterativeImputer] Ending imputation round 17/50, elapsed time 16.15
# [IterativeImputer] Change: 0.7760517542165509, scaled tolerance: 0.0250595
# [IterativeImputer] Ending imputation round 18/50, elapsed time 17.57
# [IterativeImputer] Change: 1.0486218225064046, scaled tolerance: 0.0250595
# [IterativeImputer] Ending imputation round 19/50, elapsed time 18.75
# [IterativeImputer] Change: 0.7709792098546433, scaled tolerance: 0.0250595
# [IterativeImputer] Ending imputation round 20/50, elapsed time 21.57
# [IterativeImputer] Change: 0.5892229365765752, scaled tolerance: 0.0250595
# [IterativeImputer] Ending imputation round 21/50, elapsed time 23.38
# [IterativeImputer] Change: 0.7304697537145631, scaled tolerance: 0.0250595
# [IterativeImputer] Ending imputation round 22/50, elapsed time 24.25
# [IterativeImputer] Change: 0.7676208760055534, scaled tolerance: 0.0250595
# [IterativeImputer] Ending imputation round 23/50, elapsed time 25.29
# [IterativeImputer] Change: 0.7474146690746228, scaled tolerance: 0.0250595
# [IterativeImputer] Ending imputation round 24/50, elapsed time 27.26
# [IterativeImputer] Change: 0.5557172010155151, scaled tolerance: 0.0250595
# [IterativeImputer] Ending imputation round 25/50, elapsed time 30.18
# [IterativeImputer] Change: 0.8458960102852232, scaled tolerance: 0.0250595
# [IterativeImputer] Ending imputation round 26/50, elapsed time 31.60
# [IterativeImputer] Change: 1.240463463242404, scaled tolerance: 0.0250595
# [IterativeImputer] Ending imputation round 27/50, elapsed time 32.66
# [IterativeImputer] Change: 0.7666902315381698, scaled tolerance: 0.0250595
# [IterativeImputer] Ending imputation round 28/50, elapsed time 33.88
# [IterativeImputer] Change: 0.6529428525052176, scaled tolerance: 0.0250595
# [IterativeImputer] Ending imputation round 29/50, elapsed time 35.25
# [IterativeImputer] Change: 0.9302410359603214, scaled tolerance: 0.0250595
# [IterativeImputer] Ending imputation round 30/50, elapsed time 36.34
# [IterativeImputer] Change: 0.7309229905191262, scaled tolerance: 0.0250595
# [IterativeImputer] Ending imputation round 31/50, elapsed time 37.60
# [IterativeImputer] Change: 0.9870207244804, scaled tolerance: 0.0250595
# [IterativeImputer] Ending imputation round 32/50, elapsed time 39.24
# [IterativeImputer] Change: 0.9638271711426601, scaled tolerance: 0.0250595
# [IterativeImputer] Ending imputation round 33/50, elapsed time 41.00
# [IterativeImputer] Change: 1.3340029255139578, scaled tolerance: 0.0250595
# [IterativeImputer] Ending imputation round 34/50, elapsed time 41.68
# [IterativeImputer] Change: 0.9729007630635391, scaled tolerance: 0.0250595
# [IterativeImputer] Ending imputation round 35/50, elapsed time 43.22
# [IterativeImputer] Change: 0.9464533518217799, scaled tolerance: 0.0250595
# [IterativeImputer] Ending imputation round 36/50, elapsed time 44.08
# [IterativeImputer] Change: 0.9029467592637701, scaled tolerance: 0.0250595
# [IterativeImputer] Ending imputation round 37/50, elapsed time 44.98
# [IterativeImputer] Change: 0.9055771929189643, scaled tolerance: 0.0250595
# [IterativeImputer] Ending imputation round 38/50, elapsed time 46.52
# [IterativeImputer] Change: 0.7794797937844582, scaled tolerance: 0.0250595
# [IterativeImputer] Ending imputation round 39/50, elapsed time 47.69
# [IterativeImputer] Change: 0.9158650046719576, scaled tolerance: 0.0250595
# [IterativeImputer] Ending imputation round 40/50, elapsed time 48.53
# [IterativeImputer] Change: 0.5494249899235234, scaled tolerance: 0.0250595
# [IterativeImputer] Ending imputation round 41/50, elapsed time 49.68
# [IterativeImputer] Change: 0.8828186783182677, scaled tolerance: 0.0250595
# [IterativeImputer] Ending imputation round 42/50, elapsed time 51.92
# [IterativeImputer] Change: 1.1123138298383297, scaled tolerance: 0.0250595
# [IterativeImputer] Ending imputation round 43/50, elapsed time 52.86
# [IterativeImputer] Change: 0.9354373009493875, scaled tolerance: 0.0250595
# [IterativeImputer] Ending imputation round 44/50, elapsed time 54.73
# [IterativeImputer] Change: 0.7715778942863861, scaled tolerance: 0.0250595
# [IterativeImputer] Ending imputation round 45/50, elapsed time 56.60
# [IterativeImputer] Change: 0.8431668385851253, scaled tolerance: 0.0250595
# [IterativeImputer] Ending imputation round 46/50, elapsed time 57.54
# [IterativeImputer] Change: 0.957654524103665, scaled tolerance: 0.0250595
# [IterativeImputer] Ending imputation round 47/50, elapsed time 59.00
# [IterativeImputer] Change: 0.8856995133981904, scaled tolerance: 0.0250595
# [IterativeImputer] Ending imputation round 48/50, elapsed time 60.47
# [IterativeImputer] Change: 0.8494819274214002, scaled tolerance: 0.0250595
# [IterativeImputer] Ending imputation round 49/50, elapsed time 62.62
# [IterativeImputer] Change: 0.9442998855855717, scaled tolerance: 0.0250595
# [IterativeImputer] Ending imputation round 50/50, elapsed time 64.25
# [IterativeImputer] Change: 1.1010661955185441, scaled tolerance: 0.0250595
# [IterativeImputer] Completing matrix with shape (12065, 53)
# [IterativeImputer] Ending imputation round 1/50, elapsed time 0.10
# [IterativeImputer] Ending imputation round 2/50, elapsed time 0.27
# [IterativeImputer] Ending imputation round 3/50, elapsed time 0.43
# [IterativeImputer] Ending imputation round 4/50, elapsed time 0.55
# [IterativeImputer] Ending imputation round 5/50, elapsed time 0.68
# [IterativeImputer] Ending imputation round 6/50, elapsed time 0.80
# [IterativeImputer] Ending imputation round 7/50, elapsed time 0.89
# [IterativeImputer] Ending imputation round 8/50, elapsed time 0.98
# [IterativeImputer] Ending imputation round 9/50, elapsed time 1.08
# [IterativeImputer] Ending imputation round 10/50, elapsed time 1.18
# [IterativeImputer] Ending imputation round 11/50, elapsed time 1.28
# [IterativeImputer] Ending imputation round 12/50, elapsed time 1.41
# [IterativeImputer] Ending imputation round 13/50, elapsed time 1.53
# [IterativeImputer] Ending imputation round 14/50, elapsed time 1.66
# [IterativeImputer] Ending imputation round 15/50, elapsed time 1.79
# [IterativeImputer] Ending imputation round 16/50, elapsed time 1.88
# [IterativeImputer] Ending imputation round 17/50, elapsed time 2.01
# [IterativeImputer] Ending imputation round 18/50, elapsed time 2.13
# [IterativeImputer] Ending imputation round 19/50, elapsed time 2.26
# [IterativeImputer] Ending imputation round 20/50, elapsed time 2.39
# [IterativeImputer] Ending imputation round 21/50, elapsed time 2.52
# [IterativeImputer] Ending imputation round 22/50, elapsed time 2.64
# [IterativeImputer] Ending imputation round 23/50, elapsed time 2.76
# [IterativeImputer] Ending imputation round 24/50, elapsed time 2.89
# [IterativeImputer] Ending imputation round 25/50, elapsed time 3.01
# [IterativeImputer] Ending imputation round 26/50, elapsed time 3.12
# [IterativeImputer] Ending imputation round 27/50, elapsed time 3.25
# [IterativeImputer] Ending imputation round 28/50, elapsed time 3.38
# [IterativeImputer] Ending imputation round 29/50, elapsed time 3.55
# [IterativeImputer] Ending imputation round 30/50, elapsed time 3.70
# [IterativeImputer] Ending imputation round 31/50, elapsed time 3.81
# [IterativeImputer] Ending imputation round 32/50, elapsed time 3.98
# [IterativeImputer] Ending imputation round 33/50, elapsed time 4.14
# [IterativeImputer] Ending imputation round 34/50, elapsed time 4.29
# [IterativeImputer] Ending imputation round 35/50, elapsed time 4.41
# [IterativeImputer] Ending imputation round 36/50, elapsed time 4.57
# [IterativeImputer] Ending imputation round 37/50, elapsed time 4.72
# [IterativeImputer] Ending imputation round 38/50, elapsed time 4.89
# [IterativeImputer] Ending imputation round 39/50, elapsed time 5.04
# [IterativeImputer] Ending imputation round 40/50, elapsed time 5.18
# [IterativeImputer] Ending imputation round 41/50, elapsed time 5.28
# [IterativeImputer] Ending imputation round 42/50, elapsed time 5.42
# [IterativeImputer] Ending imputation round 43/50, elapsed time 5.58
# [IterativeImputer] Ending imputation round 44/50, elapsed time 5.72
# [IterativeImputer] Ending imputation round 45/50, elapsed time 5.80
# [IterativeImputer] Ending imputation round 46/50, elapsed time 5.91
# [IterativeImputer] Ending imputation round 47/50, elapsed time 6.03
# [IterativeImputer] Ending imputation round 48/50, elapsed time 6.20
# [IterativeImputer] Ending imputation round 49/50, elapsed time 6.33
# [IterativeImputer] Ending imputation round 50/50, elapsed time 6.44
# Lasso imputation predictions saved to 'lasso_predictions.csv'.
