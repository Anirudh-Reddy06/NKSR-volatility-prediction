# %%
import pandas as pd
import numpy as np
from sklearn.experimental import enable_iterative_imputer  # noqa: F401
from sklearn.impute import IterativeImputer
from sklearn.linear_model import BayesianRidge
import warnings
warnings.filterwarnings('ignore')

# Load your data
test = pd.read_parquet('test_data.parquet')
sample_submission = pd.read_csv('sample_submission.csv')

# Identify target columns (excluding 'timestamp')
target_columns = [col for col in sample_submission.columns if col != 'timestamp']
submission = sample_submission.copy()
for col in target_columns:
    submission[col] = test[col] if col in test.columns else np.nan

# Optionally include 'underlying' if present
if 'underlying' in test.columns:
    submission['underlying'] = test['underlying']
    all_imputation_cols = target_columns + ['underlying']
else:
    all_imputation_cols = target_columns

# Setup Bayesian Ridge imputer
imputer_bayes = IterativeImputer(
    estimator=BayesianRidge(
        alpha_1=1e-6, alpha_2=1e-6,
        lambda_1=1e-6, lambda_2=1e-6,
        compute_score=True
    ),
    max_iter=60,
    tol=1e-6,
    n_nearest_features=20,
    initial_strategy='median',
    imputation_order='ascending',
    random_state=43,
    verbose=2
)

# Fit imputer on the submission data
imputer_bayes.fit(submission[all_imputation_cols])

# Transform to get imputed values
imputed_bayes = imputer_bayes.transform(submission[all_imputation_cols])

# Prepare output dataframe
bayes_pred = submission.copy()
bayes_pred[target_columns] = imputed_bayes[:, :len(target_columns)]

# Save to CSV for blending or submission
bayes_pred.to_csv('bayesianridge_imputation.csv', index=False)
print("Bayesian Ridge imputation predictions saved to 'bayesianridge_predictions.csv'.")
# Out:
# [IterativeImputer] Completing matrix with shape (12065, 53)
# [IterativeImputer] Ending imputation round 1/60, elapsed time 0.57
# [IterativeImputer] Change: 2.517904210902664, scaled tolerance: 0.0250595
# [IterativeImputer] Ending imputation round 2/60, elapsed time 1.24
# [IterativeImputer] Change: 0.564428231658536, scaled tolerance: 0.0250595
# [IterativeImputer] Ending imputation round 3/60, elapsed time 1.83
# [IterativeImputer] Change: 0.23812610508760465, scaled tolerance: 0.0250595
# [IterativeImputer] Ending imputation round 4/60, elapsed time 2.59
# [IterativeImputer] Change: 0.15845490378371854, scaled tolerance: 0.0250595
# [IterativeImputer] Ending imputation round 5/60, elapsed time 3.41
# [IterativeImputer] Change: 0.11886522512598635, scaled tolerance: 0.0250595
# [IterativeImputer] Ending imputation round 6/60, elapsed time 4.06
# [IterativeImputer] Change: 0.10234666287655461, scaled tolerance: 0.0250595
# [IterativeImputer] Ending imputation round 7/60, elapsed time 4.86
# [IterativeImputer] Change: 0.09639480303485182, scaled tolerance: 0.0250595
# [IterativeImputer] Ending imputation round 8/60, elapsed time 5.45
# [IterativeImputer] Change: 0.10040393746281473, scaled tolerance: 0.0250595
# [IterativeImputer] Ending imputation round 9/60, elapsed time 6.21
# [IterativeImputer] Change: 0.12267079408081619, scaled tolerance: 0.0250595
# [IterativeImputer] Ending imputation round 10/60, elapsed time 7.01
# [IterativeImputer] Change: 0.08653454756815851, scaled tolerance: 0.0250595
# [IterativeImputer] Ending imputation round 11/60, elapsed time 7.71
# [IterativeImputer] Change: 0.08953957969047865, scaled tolerance: 0.0250595
# [IterativeImputer] Ending imputation round 12/60, elapsed time 8.20
# [IterativeImputer] Change: 0.09947923481618301, scaled tolerance: 0.0250595
# [IterativeImputer] Ending imputation round 13/60, elapsed time 8.89
# [IterativeImputer] Change: 0.0647090056255348, scaled tolerance: 0.0250595
# [IterativeImputer] Ending imputation round 14/60, elapsed time 9.64
# [IterativeImputer] Change: 0.1273826071044849, scaled tolerance: 0.0250595
# [IterativeImputer] Ending imputation round 15/60, elapsed time 10.06
# [IterativeImputer] Change: 0.09653312867335284, scaled tolerance: 0.0250595
# [IterativeImputer] Ending imputation round 16/60, elapsed time 10.44
# [IterativeImputer] Change: 0.09122639452405334, scaled tolerance: 0.0250595
# [IterativeImputer] Ending imputation round 17/60, elapsed time 11.01
# [IterativeImputer] Change: 0.09689336350992958, scaled tolerance: 0.0250595
# [IterativeImputer] Ending imputation round 18/60, elapsed time 11.75
# [IterativeImputer] Change: 0.09057025915326972, scaled tolerance: 0.0250595
# [IterativeImputer] Ending imputation round 19/60, elapsed time 12.22
# [IterativeImputer] Change: 0.0846685504953712, scaled tolerance: 0.0250595
# [IterativeImputer] Ending imputation round 20/60, elapsed time 12.94
# [IterativeImputer] Change: 0.08880521021485216, scaled tolerance: 0.0250595
# [IterativeImputer] Ending imputation round 21/60, elapsed time 13.85
# [IterativeImputer] Change: 0.07863458699717574, scaled tolerance: 0.0250595
# [IterativeImputer] Ending imputation round 22/60, elapsed time 14.28
# [IterativeImputer] Change: 0.08170973305720086, scaled tolerance: 0.0250595
# [IterativeImputer] Ending imputation round 23/60, elapsed time 14.99
# [IterativeImputer] Change: 0.07301851768701309, scaled tolerance: 0.0250595
# [IterativeImputer] Ending imputation round 24/60, elapsed time 15.83
# [IterativeImputer] Change: 0.08766990276794348, scaled tolerance: 0.0250595
# [IterativeImputer] Ending imputation round 25/60, elapsed time 16.40
# [IterativeImputer] Change: 0.0967686737180925, scaled tolerance: 0.0250595
# [IterativeImputer] Ending imputation round 26/60, elapsed time 16.87
# [IterativeImputer] Change: 0.071956538699846, scaled tolerance: 0.0250595
# [IterativeImputer] Ending imputation round 27/60, elapsed time 17.53
# [IterativeImputer] Change: 0.08477883454305818, scaled tolerance: 0.0250595
# [IterativeImputer] Ending imputation round 28/60, elapsed time 17.89
# [IterativeImputer] Change: 0.09330048292424667, scaled tolerance: 0.0250595
# [IterativeImputer] Ending imputation round 29/60, elapsed time 18.50
# [IterativeImputer] Change: 0.06976845694184639, scaled tolerance: 0.0250595
# [IterativeImputer] Ending imputation round 30/60, elapsed time 19.26
# [IterativeImputer] Change: 0.08240565397713531, scaled tolerance: 0.0250595
# [IterativeImputer] Ending imputation round 31/60, elapsed time 19.70
# [IterativeImputer] Change: 0.0644738097238799, scaled tolerance: 0.0250595
# [IterativeImputer] Ending imputation round 32/60, elapsed time 20.44
# [IterativeImputer] Change: 0.07166124011347272, scaled tolerance: 0.0250595
# [IterativeImputer] Ending imputation round 33/60, elapsed time 20.87
# [IterativeImputer] Change: 0.07960595751858746, scaled tolerance: 0.0250595
# [IterativeImputer] Ending imputation round 34/60, elapsed time 21.61
# [IterativeImputer] Change: 0.06007457533829447, scaled tolerance: 0.0250595
# [IterativeImputer] Ending imputation round 35/60, elapsed time 22.34
# [IterativeImputer] Change: 0.08856488360960602, scaled tolerance: 0.0250595
# [IterativeImputer] Ending imputation round 36/60, elapsed time 22.72
# [IterativeImputer] Change: 0.08493145031876079, scaled tolerance: 0.0250595
# [IterativeImputer] Ending imputation round 37/60, elapsed time 23.08
# [IterativeImputer] Change: 0.0820348637290986, scaled tolerance: 0.0250595
# [IterativeImputer] Ending imputation round 38/60, elapsed time 23.45
# [IterativeImputer] Change: 0.07425894873853786, scaled tolerance: 0.0250595
# [IterativeImputer] Ending imputation round 39/60, elapsed time 23.82
# [IterativeImputer] Change: 0.08370374882853357, scaled tolerance: 0.0250595
# [IterativeImputer] Ending imputation round 40/60, elapsed time 24.17
# [IterativeImputer] Change: 0.0737996683806989, scaled tolerance: 0.0250595
# [IterativeImputer] Ending imputation round 41/60, elapsed time 24.53
# [IterativeImputer] Change: 0.09619241068542636, scaled tolerance: 0.0250595
# [IterativeImputer] Ending imputation round 42/60, elapsed time 24.88
# [IterativeImputer] Change: 0.08250140419481064, scaled tolerance: 0.0250595
# [IterativeImputer] Ending imputation round 43/60, elapsed time 25.29
# [IterativeImputer] Change: 0.08730962698058065, scaled tolerance: 0.0250595
# [IterativeImputer] Ending imputation round 44/60, elapsed time 25.67
# [IterativeImputer] Change: 0.08291543263446119, scaled tolerance: 0.0250595
# [IterativeImputer] Ending imputation round 45/60, elapsed time 26.03
# [IterativeImputer] Change: 0.08667967968542495, scaled tolerance: 0.0250595
# [IterativeImputer] Ending imputation round 46/60, elapsed time 26.50
# [IterativeImputer] Change: 0.0857786275206745, scaled tolerance: 0.0250595
# [IterativeImputer] Ending imputation round 47/60, elapsed time 27.26
# [IterativeImputer] Change: 0.09062742061654122, scaled tolerance: 0.0250595
# [IterativeImputer] Ending imputation round 48/60, elapsed time 27.86
# [IterativeImputer] Change: 0.06611152543037072, scaled tolerance: 0.0250595
# [IterativeImputer] Ending imputation round 49/60, elapsed time 28.50
# [IterativeImputer] Change: 0.06519800182544205, scaled tolerance: 0.0250595
# [IterativeImputer] Ending imputation round 50/60, elapsed time 29.13
# [IterativeImputer] Change: 0.07062512378204386, scaled tolerance: 0.0250595
# [IterativeImputer] Ending imputation round 51/60, elapsed time 29.56
# [IterativeImputer] Change: 0.06976421479044254, scaled tolerance: 0.0250595
# [IterativeImputer] Ending imputation round 52/60, elapsed time 30.26
# [IterativeImputer] Change: 0.11599275076180213, scaled tolerance: 0.0250595
# [IterativeImputer] Ending imputation round 53/60, elapsed time 30.66
# [IterativeImputer] Change: 0.1155385202159458, scaled tolerance: 0.0250595
# [IterativeImputer] Ending imputation round 54/60, elapsed time 31.14
# [IterativeImputer] Change: 0.0879322455571451, scaled tolerance: 0.0250595
# [IterativeImputer] Ending imputation round 55/60, elapsed time 31.73
# [IterativeImputer] Change: 0.08771077557304319, scaled tolerance: 0.0250595
# [IterativeImputer] Ending imputation round 56/60, elapsed time 32.36
# [IterativeImputer] Change: 0.0815123393170872, scaled tolerance: 0.0250595
# [IterativeImputer] Ending imputation round 57/60, elapsed time 32.78
# [IterativeImputer] Change: 0.09442225795331072, scaled tolerance: 0.0250595
# [IterativeImputer] Ending imputation round 58/60, elapsed time 33.31
# [IterativeImputer] Change: 0.07996664988815733, scaled tolerance: 0.0250595
# [IterativeImputer] Ending imputation round 59/60, elapsed time 34.03
# [IterativeImputer] Change: 0.0738336581924007, scaled tolerance: 0.0250595
# [IterativeImputer] Ending imputation round 60/60, elapsed time 34.82
# [IterativeImputer] Change: 0.07374951182238218, scaled tolerance: 0.0250595
# [IterativeImputer] Completing matrix with shape (12065, 53)
# [IterativeImputer] Ending imputation round 1/60, elapsed time 0.07
# [IterativeImputer] Ending imputation round 2/60, elapsed time 0.14
# [IterativeImputer] Ending imputation round 3/60, elapsed time 0.19
# [IterativeImputer] Ending imputation round 4/60, elapsed time 0.27
# [IterativeImputer] Ending imputation round 5/60, elapsed time 0.34
# [IterativeImputer] Ending imputation round 6/60, elapsed time 0.40
# [IterativeImputer] Ending imputation round 7/60, elapsed time 0.47
# [IterativeImputer] Ending imputation round 8/60, elapsed time 0.54
# [IterativeImputer] Ending imputation round 9/60, elapsed time 0.60
# [IterativeImputer] Ending imputation round 10/60, elapsed time 0.68
# [IterativeImputer] Ending imputation round 11/60, elapsed time 0.76
# [IterativeImputer] Ending imputation round 12/60, elapsed time 0.83
# [IterativeImputer] Ending imputation round 13/60, elapsed time 0.90
# [IterativeImputer] Ending imputation round 14/60, elapsed time 0.98
# [IterativeImputer] Ending imputation round 15/60, elapsed time 1.04
# [IterativeImputer] Ending imputation round 16/60, elapsed time 1.11
# [IterativeImputer] Ending imputation round 17/60, elapsed time 1.19
# [IterativeImputer] Ending imputation round 18/60, elapsed time 1.26
# [IterativeImputer] Ending imputation round 19/60, elapsed time 1.33
# [IterativeImputer] Ending imputation round 20/60, elapsed time 1.40
# [IterativeImputer] Ending imputation round 21/60, elapsed time 1.48
# [IterativeImputer] Ending imputation round 22/60, elapsed time 1.54
# [IterativeImputer] Ending imputation round 23/60, elapsed time 1.61
# [IterativeImputer] Ending imputation round 24/60, elapsed time 1.69
# [IterativeImputer] Ending imputation round 25/60, elapsed time 1.76
# [IterativeImputer] Ending imputation round 26/60, elapsed time 1.82
# [IterativeImputer] Ending imputation round 27/60, elapsed time 1.90
# [IterativeImputer] Ending imputation round 28/60, elapsed time 1.96
# [IterativeImputer] Ending imputation round 29/60, elapsed time 2.03
# [IterativeImputer] Ending imputation round 30/60, elapsed time 2.10
# [IterativeImputer] Ending imputation round 31/60, elapsed time 2.17
# [IterativeImputer] Ending imputation round 32/60, elapsed time 2.24
# [IterativeImputer] Ending imputation round 33/60, elapsed time 2.31
# [IterativeImputer] Ending imputation round 34/60, elapsed time 2.41
# [IterativeImputer] Ending imputation round 35/60, elapsed time 2.47
# [IterativeImputer] Ending imputation round 36/60, elapsed time 2.55
# [IterativeImputer] Ending imputation round 37/60, elapsed time 2.64
# [IterativeImputer] Ending imputation round 38/60, elapsed time 2.71
# [IterativeImputer] Ending imputation round 39/60, elapsed time 2.81
# [IterativeImputer] Ending imputation round 40/60, elapsed time 2.88
# [IterativeImputer] Ending imputation round 41/60, elapsed time 2.94
# [IterativeImputer] Ending imputation round 42/60, elapsed time 3.01
# [IterativeImputer] Ending imputation round 43/60, elapsed time 3.09
# [IterativeImputer] Ending imputation round 44/60, elapsed time 3.16
# [IterativeImputer] Ending imputation round 45/60, elapsed time 3.22
# [IterativeImputer] Ending imputation round 46/60, elapsed time 3.29
# [IterativeImputer] Ending imputation round 47/60, elapsed time 3.37
# [IterativeImputer] Ending imputation round 48/60, elapsed time 3.44
# [IterativeImputer] Ending imputation round 49/60, elapsed time 3.51
# [IterativeImputer] Ending imputation round 50/60, elapsed time 3.58
# [IterativeImputer] Ending imputation round 51/60, elapsed time 3.65
# [IterativeImputer] Ending imputation round 52/60, elapsed time 3.74
# [IterativeImputer] Ending imputation round 53/60, elapsed time 3.82
# [IterativeImputer] Ending imputation round 54/60, elapsed time 3.89
# [IterativeImputer] Ending imputation round 55/60, elapsed time 3.98
# [IterativeImputer] Ending imputation round 56/60, elapsed time 4.04
# [IterativeImputer] Ending imputation round 57/60, elapsed time 4.11
# [IterativeImputer] Ending imputation round 58/60, elapsed time 4.18
# [IterativeImputer] Ending imputation round 59/60, elapsed time 4.24
# [IterativeImputer] Ending imputation round 60/60, elapsed time 4.31
# Bayesian Ridge imputation predictions saved to 'bayesianridge_predictions.csv'.
