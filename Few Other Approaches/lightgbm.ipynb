# %%
import pandas as pd
import numpy as np
from sklearn.experimental import enable_iterative_imputer
from sklearn.impute import IterativeImputer
from lightgbm import LGBMRegressor
import warnings
warnings.filterwarnings('ignore')

# Load your data
test = pd.read_parquet('test_data.parquet')
sample_submission = pd.read_csv('sample_submission.csv')

target_columns = [col for col in sample_submission.columns if col != 'timestamp']
submission = sample_submission.copy()
for col in target_columns:
    submission[col] = test[col] if col in test.columns else np.nan
if 'underlying' in test.columns:
    submission['underlying'] = test['underlying']
    all_imputation_cols = target_columns + ['underlying']
else:
    all_imputation_cols = target_columns

imputer_lgbm = IterativeImputer(
    estimator=LGBMRegressor(
        n_estimators=500,
        max_depth=6,
        learning_rate=0.1,
        random_state=42,
        verbose=-1
    ),
    max_iter=50,
    tol=1e-6,
    n_nearest_features=20,
    initial_strategy='median',
    imputation_order='ascending',
    random_state=42,
    verbose=2
)
imputer_lgbm.fit(submission[all_imputation_cols])
imputed_lgbm = imputer_lgbm.transform(submission[all_imputation_cols])
lgbm_pred = submission.copy()
lgbm_pred[target_columns] = imputed_lgbm[:, :len(target_columns)]
lgbm_pred.to_csv('lightgbm_imputation.csv', index=False)
print("LightGBM imputation predictions saved to 'lightgbm_predictions.csv'.")
# Out:
# [IterativeImputer] Completing matrix with shape (12065, 53)
# [IterativeImputer] Ending imputation round 1/50, elapsed time 48.00
# [IterativeImputer] Change: 2.6391588201183693, scaled tolerance: 0.0250595
# [IterativeImputer] Ending imputation round 2/50, elapsed time 97.30
# [IterativeImputer] Change: 0.27911239878329913, scaled tolerance: 0.0250595
# [IterativeImputer] Ending imputation round 3/50, elapsed time 127.92
# [IterativeImputer] Change: 0.13564571442387852, scaled tolerance: 0.0250595
# [IterativeImputer] Ending imputation round 4/50, elapsed time 170.93
# [IterativeImputer] Change: 0.10031636774516003, scaled tolerance: 0.0250595
# [IterativeImputer] Ending imputation round 5/50, elapsed time 202.32
# [IterativeImputer] Change: 0.08337576548446252, scaled tolerance: 0.0250595
# [IterativeImputer] Ending imputation round 6/50, elapsed time 232.97
# [IterativeImputer] Change: 0.1952745916129942, scaled tolerance: 0.0250595
# [IterativeImputer] Ending imputation round 7/50, elapsed time 263.50
# [IterativeImputer] Change: 0.19692525032346223, scaled tolerance: 0.0250595
# [IterativeImputer] Ending imputation round 8/50, elapsed time 294.53
# [IterativeImputer] Change: 0.1673786740649773, scaled tolerance: 0.0250595
# [IterativeImputer] Ending imputation round 9/50, elapsed time 324.94
# [IterativeImputer] Change: 0.16359697738405363, scaled tolerance: 0.0250595
# [IterativeImputer] Ending imputation round 10/50, elapsed time 355.02
# [IterativeImputer] Change: 0.18028319688012678, scaled tolerance: 0.0250595
# [IterativeImputer] Ending imputation round 11/50, elapsed time 386.28
# [IterativeImputer] Change: 0.16600992441519513, scaled tolerance: 0.0250595
# [IterativeImputer] Ending imputation round 12/50, elapsed time 416.37
# [IterativeImputer] Change: 0.1743480666504178, scaled tolerance: 0.0250595
# [IterativeImputer] Ending imputation round 13/50, elapsed time 439.31
# [IterativeImputer] Change: 0.13064741946798047, scaled tolerance: 0.0250595
# [IterativeImputer] Ending imputation round 14/50, elapsed time 450.40
# [IterativeImputer] Change: 0.1445344890881885, scaled tolerance: 0.0250595
# [IterativeImputer] Ending imputation round 15/50, elapsed time 461.01
# [IterativeImputer] Change: 0.14070516143881315, scaled tolerance: 0.0250595
# [IterativeImputer] Ending imputation round 16/50, elapsed time 471.34
# [IterativeImputer] Change: 0.13925007532575195, scaled tolerance: 0.0250595
# [IterativeImputer] Ending imputation round 17/50, elapsed time 481.88
# [IterativeImputer] Change: 0.10042538341394874, scaled tolerance: 0.0250595
# [IterativeImputer] Ending imputation round 18/50, elapsed time 492.20
# [IterativeImputer] Change: 0.1354701301098747, scaled tolerance: 0.0250595
# [IterativeImputer] Ending imputation round 19/50, elapsed time 502.28
# [IterativeImputer] Change: 0.1407596186693418, scaled tolerance: 0.0250595
# [IterativeImputer] Ending imputation round 20/50, elapsed time 512.35
# [IterativeImputer] Change: 0.1443065069274324, scaled tolerance: 0.0250595
# [IterativeImputer] Ending imputation round 21/50, elapsed time 522.75
# [IterativeImputer] Change: 0.08074605160380141, scaled tolerance: 0.0250595
# [IterativeImputer] Ending imputation round 22/50, elapsed time 532.90
# [IterativeImputer] Change: 0.15963493345523025, scaled tolerance: 0.0250595
# [IterativeImputer] Ending imputation round 23/50, elapsed time 543.02
# [IterativeImputer] Change: 0.13668571286384898, scaled tolerance: 0.0250595
# [IterativeImputer] Ending imputation round 24/50, elapsed time 553.10
# [IterativeImputer] Change: 0.15859714818000895, scaled tolerance: 0.0250595
# [IterativeImputer] Ending imputation round 25/50, elapsed time 563.60
# [IterativeImputer] Change: 0.16293395122303247, scaled tolerance: 0.0250595
# [IterativeImputer] Ending imputation round 26/50, elapsed time 573.88
# [IterativeImputer] Change: 0.17203818192604384, scaled tolerance: 0.0250595
# [IterativeImputer] Ending imputation round 27/50, elapsed time 584.31
# [IterativeImputer] Change: 0.14913351379860065, scaled tolerance: 0.0250595
# [IterativeImputer] Ending imputation round 28/50, elapsed time 594.86
# [IterativeImputer] Change: 0.11175643499776197, scaled tolerance: 0.0250595
# [IterativeImputer] Ending imputation round 29/50, elapsed time 604.95
# [IterativeImputer] Change: 0.20240301070065383, scaled tolerance: 0.0250595
# [IterativeImputer] Ending imputation round 30/50, elapsed time 615.12
# [IterativeImputer] Change: 0.2377665430090201, scaled tolerance: 0.0250595
# [IterativeImputer] Ending imputation round 31/50, elapsed time 625.89
# [IterativeImputer] Change: 0.25264225089616243, scaled tolerance: 0.0250595
# [IterativeImputer] Ending imputation round 32/50, elapsed time 636.26
# [IterativeImputer] Change: 0.18367826777308105, scaled tolerance: 0.0250595
# [IterativeImputer] Ending imputation round 33/50, elapsed time 646.49
# [IterativeImputer] Change: 0.14982862878405875, scaled tolerance: 0.0250595
# [IterativeImputer] Ending imputation round 34/50, elapsed time 657.27
# [IterativeImputer] Change: 0.17240626626581582, scaled tolerance: 0.0250595
# [IterativeImputer] Ending imputation round 35/50, elapsed time 667.51
# [IterativeImputer] Change: 0.15274161284938015, scaled tolerance: 0.0250595
# [IterativeImputer] Ending imputation round 36/50, elapsed time 677.80
# [IterativeImputer] Change: 0.1526676876964518, scaled tolerance: 0.0250595
# [IterativeImputer] Ending imputation round 37/50, elapsed time 688.27
# [IterativeImputer] Change: 0.19411567289943435, scaled tolerance: 0.0250595
# [IterativeImputer] Ending imputation round 38/50, elapsed time 699.16
# [IterativeImputer] Change: 0.14475083632151375, scaled tolerance: 0.0250595
# [IterativeImputer] Ending imputation round 39/50, elapsed time 709.47
# [IterativeImputer] Change: 0.13713600199793557, scaled tolerance: 0.0250595
# [IterativeImputer] Ending imputation round 40/50, elapsed time 720.04
# [IterativeImputer] Change: 0.13827986646543933, scaled tolerance: 0.0250595
# [IterativeImputer] Ending imputation round 41/50, elapsed time 751.50
# [IterativeImputer] Change: 0.16414939260294786, scaled tolerance: 0.0250595
# [IterativeImputer] Ending imputation round 42/50, elapsed time 782.50
# [IterativeImputer] Change: 0.19013061803150128, scaled tolerance: 0.0250595
# [IterativeImputer] Ending imputation round 43/50, elapsed time 812.88
# [IterativeImputer] Change: 0.1136610792512269, scaled tolerance: 0.0250595
# [IterativeImputer] Ending imputation round 44/50, elapsed time 844.09
# [IterativeImputer] Change: 0.19869437076427884, scaled tolerance: 0.0250595
# [IterativeImputer] Ending imputation round 45/50, elapsed time 876.40
# [IterativeImputer] Change: 0.2809468899782307, scaled tolerance: 0.0250595
# [IterativeImputer] Ending imputation round 46/50, elapsed time 908.33
# [IterativeImputer] Change: 0.15092992559483742, scaled tolerance: 0.0250595
# [IterativeImputer] Ending imputation round 47/50, elapsed time 939.23
# [IterativeImputer] Change: 0.13623124206448803, scaled tolerance: 0.0250595
# [IterativeImputer] Ending imputation round 48/50, elapsed time 969.41
# [IterativeImputer] Change: 0.09859483826548171, scaled tolerance: 0.0250595
# [IterativeImputer] Ending imputation round 49/50, elapsed time 1000.08
# [IterativeImputer] Change: 0.1468399318921086, scaled tolerance: 0.0250595
# [IterativeImputer] Ending imputation round 50/50, elapsed time 1031.70
# [IterativeImputer] Change: 0.16136962821383144, scaled tolerance: 0.0250595
# [IterativeImputer] Completing matrix with shape (12065, 53)
# [IterativeImputer] Ending imputation round 1/50, elapsed time 1.96
# [IterativeImputer] Ending imputation round 2/50, elapsed time 3.82
# [IterativeImputer] Ending imputation round 3/50, elapsed time 5.62
# [IterativeImputer] Ending imputation round 4/50, elapsed time 7.41
# [IterativeImputer] Ending imputation round 5/50, elapsed time 9.20
# [IterativeImputer] Ending imputation round 6/50, elapsed time 10.98
# [IterativeImputer] Ending imputation round 7/50, elapsed time 12.81
# [IterativeImputer] Ending imputation round 8/50, elapsed time 14.62
# [IterativeImputer] Ending imputation round 9/50, elapsed time 16.42
# [IterativeImputer] Ending imputation round 10/50, elapsed time 18.26
# [IterativeImputer] Ending imputation round 11/50, elapsed time 20.01
# [IterativeImputer] Ending imputation round 12/50, elapsed time 21.77
# [IterativeImputer] Ending imputation round 13/50, elapsed time 23.53
# [IterativeImputer] Ending imputation round 14/50, elapsed time 25.33
# [IterativeImputer] Ending imputation round 15/50, elapsed time 27.18
# [IterativeImputer] Ending imputation round 16/50, elapsed time 28.95
# [IterativeImputer] Ending imputation round 17/50, elapsed time 30.74
# [IterativeImputer] Ending imputation round 18/50, elapsed time 32.55
# [IterativeImputer] Ending imputation round 19/50, elapsed time 34.36
# [IterativeImputer] Ending imputation round 20/50, elapsed time 36.17
# [IterativeImputer] Ending imputation round 21/50, elapsed time 38.01
# [IterativeImputer] Ending imputation round 22/50, elapsed time 39.85
# [IterativeImputer] Ending imputation round 23/50, elapsed time 41.71
# [IterativeImputer] Ending imputation round 24/50, elapsed time 43.59
# [IterativeImputer] Ending imputation round 25/50, elapsed time 45.48
# [IterativeImputer] Ending imputation round 26/50, elapsed time 47.35
# [IterativeImputer] Ending imputation round 27/50, elapsed time 49.22
# [IterativeImputer] Ending imputation round 28/50, elapsed time 51.05
# [IterativeImputer] Ending imputation round 29/50, elapsed time 52.94
# [IterativeImputer] Ending imputation round 30/50, elapsed time 54.79
# [IterativeImputer] Ending imputation round 31/50, elapsed time 56.64
# [IterativeImputer] Ending imputation round 32/50, elapsed time 58.49
# [IterativeImputer] Ending imputation round 33/50, elapsed time 60.30
# [IterativeImputer] Ending imputation round 34/50, elapsed time 62.13
# [IterativeImputer] Ending imputation round 35/50, elapsed time 64.01
# [IterativeImputer] Ending imputation round 36/50, elapsed time 65.81
# [IterativeImputer] Ending imputation round 37/50, elapsed time 67.57
# [IterativeImputer] Ending imputation round 38/50, elapsed time 69.32
# [IterativeImputer] Ending imputation round 39/50, elapsed time 71.07
# [IterativeImputer] Ending imputation round 40/50, elapsed time 72.86
# [IterativeImputer] Ending imputation round 41/50, elapsed time 74.61
# [IterativeImputer] Ending imputation round 42/50, elapsed time 76.32
# [IterativeImputer] Ending imputation round 43/50, elapsed time 78.03
# [IterativeImputer] Ending imputation round 44/50, elapsed time 79.81
# [IterativeImputer] Ending imputation round 45/50, elapsed time 81.57
# [IterativeImputer] Ending imputation round 46/50, elapsed time 83.32
# [IterativeImputer] Ending imputation round 47/50, elapsed time 85.06
# [IterativeImputer] Ending imputation round 48/50, elapsed time 86.83
# [IterativeImputer] Ending imputation round 49/50, elapsed time 88.56
# [IterativeImputer] Ending imputation round 50/50, elapsed time 90.30
# LightGBM imputation predictions saved to 'lightgbm_predictions.csv'.
