# %%
import pandas as pd
import numpy as np
from sklearn.experimental import enable_iterative_imputer
from sklearn.impute import IterativeImputer
from catboost import CatBoostRegressor
import warnings
warnings.filterwarnings('ignore')

# Load your data
test = pd.read_parquet('test_data.parquet')
sample_submission = pd.read_csv('sample_submission.csv')

target_columns = [col for col in sample_submission.columns if col != 'timestamp']
submission = sample_submission.copy()
for col in target_columns:
    submission[col] = test[col] if col in test.columns else np.nan
if 'underlying' in test.columns:
    submission['underlying'] = test['underlying']
    all_imputation_cols = target_columns + ['underlying']
else:
    all_imputation_cols = target_columns

imputer_catboost = IterativeImputer(
    estimator=CatBoostRegressor(
        iterations=500,
        depth=6,
        learning_rate=0.1,
        loss_function='RMSE',
        random_seed=42,
        verbose=0
    ),
    max_iter=50,
    tol=1e-6,
    n_nearest_features=20,
    initial_strategy='median',
    imputation_order='ascending',
    random_state=42,
    verbose=2
)
imputer_catboost.fit(submission[all_imputation_cols])
imputed_catboost = imputer_catboost.transform(submission[all_imputation_cols])
catboost_pred = submission.copy()
catboost_pred[target_columns] = imputed_catboost[:, :len(target_columns)]
catboost_pred.to_csv('catboost_imputation.csv', index=False)
print("CatBoost imputation predictions saved to 'catboost_predictions.csv'.")
# Out:
# [IterativeImputer] Completing matrix with shape (12065, 53)
# [IterativeImputer] Ending imputation round 1/50, elapsed time 83.30
# [IterativeImputer] Change: 2.6146263128476126, scaled tolerance: 0.0250595
# [IterativeImputer] Ending imputation round 2/50, elapsed time 181.58
# [IterativeImputer] Change: 0.2340327676329423, scaled tolerance: 0.0250595
# [IterativeImputer] Ending imputation round 3/50, elapsed time 295.93
# [IterativeImputer] Change: 0.13321532238969774, scaled tolerance: 0.0250595
# [IterativeImputer] Ending imputation round 4/50, elapsed time 406.23
# [IterativeImputer] Change: 0.09352316177350267, scaled tolerance: 0.0250595
# [IterativeImputer] Ending imputation round 5/50, elapsed time 506.10
# [IterativeImputer] Change: 0.08337679066600082, scaled tolerance: 0.0250595
# [IterativeImputer] Ending imputation round 6/50, elapsed time 604.74
# [IterativeImputer] Change: 0.08780202615536484, scaled tolerance: 0.0250595
# [IterativeImputer] Ending imputation round 7/50, elapsed time 681.38
# [IterativeImputer] Change: 0.09693060797134717, scaled tolerance: 0.0250595
# [IterativeImputer] Ending imputation round 8/50, elapsed time 759.20
# [IterativeImputer] Change: 0.06854503801063652, scaled tolerance: 0.0250595
# [IterativeImputer] Ending imputation round 9/50, elapsed time 852.38
# [IterativeImputer] Change: 0.0797415926030115, scaled tolerance: 0.0250595
# [IterativeImputer] Ending imputation round 10/50, elapsed time 926.14
# [IterativeImputer] Change: 0.07534538731224877, scaled tolerance: 0.0250595
# [IterativeImputer] Ending imputation round 11/50, elapsed time 997.47
# [IterativeImputer] Change: 0.0808427484203344, scaled tolerance: 0.0250595
# [IterativeImputer] Ending imputation round 12/50, elapsed time 1070.89
# [IterativeImputer] Change: 0.07065986914428823, scaled tolerance: 0.0250595
# [IterativeImputer] Ending imputation round 13/50, elapsed time 1140.80
# [IterativeImputer] Change: 0.07962983028615853, scaled tolerance: 0.0250595
# [IterativeImputer] Ending imputation round 14/50, elapsed time 1213.74
# [IterativeImputer] Change: 0.0845022188539912, scaled tolerance: 0.0250595
# [IterativeImputer] Ending imputation round 15/50, elapsed time 1289.58
# [IterativeImputer] Change: 0.08808678217098045, scaled tolerance: 0.0250595
# [IterativeImputer] Ending imputation round 16/50, elapsed time 1364.71
# [IterativeImputer] Change: 0.08266729157561145, scaled tolerance: 0.0250595
# [IterativeImputer] Ending imputation round 17/50, elapsed time 1450.98
# [IterativeImputer] Change: 0.09068384167174282, scaled tolerance: 0.0250595
# [IterativeImputer] Ending imputation round 18/50, elapsed time 1551.18
# [IterativeImputer] Change: 0.11371519082158782, scaled tolerance: 0.0250595
# [IterativeImputer] Ending imputation round 19/50, elapsed time 1629.99
# [IterativeImputer] Change: 0.11607691371694812, scaled tolerance: 0.0250595
# [IterativeImputer] Ending imputation round 20/50, elapsed time 1704.57
# [IterativeImputer] Change: 0.08166696945266785, scaled tolerance: 0.0250595
# [IterativeImputer] Ending imputation round 21/50, elapsed time 1783.57
# [IterativeImputer] Change: 0.0803078561665938, scaled tolerance: 0.0250595
# [IterativeImputer] Ending imputation round 22/50, elapsed time 1891.72
# [IterativeImputer] Change: 0.07311714444924583, scaled tolerance: 0.0250595
# [IterativeImputer] Ending imputation round 23/50, elapsed time 2049.57
# [IterativeImputer] Change: 0.08760736186644516, scaled tolerance: 0.0250595
# [IterativeImputer] Ending imputation round 24/50, elapsed time 2174.28
# [IterativeImputer] Change: 0.08929909874251774, scaled tolerance: 0.0250595
# [IterativeImputer] Ending imputation round 25/50, elapsed time 2334.01
# [IterativeImputer] Change: 0.08967110657562524, scaled tolerance: 0.0250595
# [IterativeImputer] Ending imputation round 26/50, elapsed time 2486.62
# [IterativeImputer] Change: 0.09435949676125316, scaled tolerance: 0.0250595
# [IterativeImputer] Ending imputation round 27/50, elapsed time 2623.28
# [IterativeImputer] Change: 0.08921530741726899, scaled tolerance: 0.0250595
# [IterativeImputer] Ending imputation round 28/50, elapsed time 2747.95
# [IterativeImputer] Change: 0.07689681831465564, scaled tolerance: 0.0250595
# [IterativeImputer] Ending imputation round 29/50, elapsed time 2882.42
# [IterativeImputer] Change: 0.06770934254574276, scaled tolerance: 0.0250595
# [IterativeImputer] Ending imputation round 30/50, elapsed time 3005.75
# [IterativeImputer] Change: 0.06621261787626057, scaled tolerance: 0.0250595
# [IterativeImputer] Ending imputation round 31/50, elapsed time 3122.03
# [IterativeImputer] Change: 0.08015635899700135, scaled tolerance: 0.0250595
# [IterativeImputer] Ending imputation round 32/50, elapsed time 3236.34
# [IterativeImputer] Change: 0.0974438433793566, scaled tolerance: 0.0250595
# [IterativeImputer] Ending imputation round 33/50, elapsed time 3368.81
# [IterativeImputer] Change: 0.09062165269906777, scaled tolerance: 0.0250595
# [IterativeImputer] Ending imputation round 34/50, elapsed time 3512.22
# [IterativeImputer] Change: 0.08057312865061286, scaled tolerance: 0.0250595
# [IterativeImputer] Ending imputation round 35/50, elapsed time 3631.05
# [IterativeImputer] Change: 0.0875322161669182, scaled tolerance: 0.0250595
# [IterativeImputer] Ending imputation round 36/50, elapsed time 3749.05
# [IterativeImputer] Change: 0.10321210057172875, scaled tolerance: 0.0250595
# [IterativeImputer] Ending imputation round 37/50, elapsed time 3866.08
# [IterativeImputer] Change: 0.08593915012730827, scaled tolerance: 0.0250595
# [IterativeImputer] Ending imputation round 38/50, elapsed time 3982.10
# [IterativeImputer] Change: 0.08899614251856527, scaled tolerance: 0.0250595
# [IterativeImputer] Ending imputation round 39/50, elapsed time 4071.68
# [IterativeImputer] Change: 0.08756559968022326, scaled tolerance: 0.0250595
# [IterativeImputer] Ending imputation round 40/50, elapsed time 4142.58
# [IterativeImputer] Change: 0.09286155406075017, scaled tolerance: 0.0250595
# [IterativeImputer] Ending imputation round 41/50, elapsed time 4212.87
# [IterativeImputer] Change: 0.0921349716518958, scaled tolerance: 0.0250595
# [IterativeImputer] Ending imputation round 42/50, elapsed time 4286.70
# [IterativeImputer] Change: 0.07859648680630457, scaled tolerance: 0.0250595
# [IterativeImputer] Ending imputation round 43/50, elapsed time 4361.46
# [IterativeImputer] Change: 0.08101652216585553, scaled tolerance: 0.0250595
# [IterativeImputer] Ending imputation round 44/50, elapsed time 4433.15
# [IterativeImputer] Change: 0.08182183668030965, scaled tolerance: 0.0250595
# [IterativeImputer] Ending imputation round 45/50, elapsed time 4505.47
# [IterativeImputer] Change: 0.09565490751440026, scaled tolerance: 0.0250595
# [IterativeImputer] Ending imputation round 46/50, elapsed time 4579.25
# [IterativeImputer] Change: 0.10200112451782889, scaled tolerance: 0.0250595
# [IterativeImputer] Ending imputation round 47/50, elapsed time 4652.52
# [IterativeImputer] Change: 0.1289434158144719, scaled tolerance: 0.0250595
# [IterativeImputer] Ending imputation round 48/50, elapsed time 4724.57
# [IterativeImputer] Change: 0.09964153942623036, scaled tolerance: 0.0250595
# [IterativeImputer] Ending imputation round 49/50, elapsed time 4797.97
# [IterativeImputer] Change: 0.11308226197709093, scaled tolerance: 0.0250595
# [IterativeImputer] Ending imputation round 50/50, elapsed time 4870.77
# [IterativeImputer] Change: 0.10960613590227708, scaled tolerance: 0.0250595
# [IterativeImputer] Completing matrix with shape (12065, 53)
# [IterativeImputer] Ending imputation round 1/50, elapsed time 1.57
# [IterativeImputer] Ending imputation round 2/50, elapsed time 3.17
# [IterativeImputer] Ending imputation round 3/50, elapsed time 4.74
# [IterativeImputer] Ending imputation round 4/50, elapsed time 6.31
# [IterativeImputer] Ending imputation round 5/50, elapsed time 7.92
# [IterativeImputer] Ending imputation round 6/50, elapsed time 9.38
# [IterativeImputer] Ending imputation round 7/50, elapsed time 10.94
# [IterativeImputer] Ending imputation round 8/50, elapsed time 12.44
# [IterativeImputer] Ending imputation round 9/50, elapsed time 13.92
# [IterativeImputer] Ending imputation round 10/50, elapsed time 15.39
# [IterativeImputer] Ending imputation round 11/50, elapsed time 16.87
# [IterativeImputer] Ending imputation round 12/50, elapsed time 18.40
# [IterativeImputer] Ending imputation round 13/50, elapsed time 19.99
# [IterativeImputer] Ending imputation round 14/50, elapsed time 21.49
# [IterativeImputer] Ending imputation round 15/50, elapsed time 22.96
# [IterativeImputer] Ending imputation round 16/50, elapsed time 24.52
# [IterativeImputer] Ending imputation round 17/50, elapsed time 26.06
# [IterativeImputer] Ending imputation round 18/50, elapsed time 27.54
# [IterativeImputer] Ending imputation round 19/50, elapsed time 29.16
# [IterativeImputer] Ending imputation round 20/50, elapsed time 30.63
# [IterativeImputer] Ending imputation round 21/50, elapsed time 32.10
# [IterativeImputer] Ending imputation round 22/50, elapsed time 33.60
# [IterativeImputer] Ending imputation round 23/50, elapsed time 35.07
# [IterativeImputer] Ending imputation round 24/50, elapsed time 36.57
# [IterativeImputer] Ending imputation round 25/50, elapsed time 38.05
# [IterativeImputer] Ending imputation round 26/50, elapsed time 39.59
# [IterativeImputer] Ending imputation round 27/50, elapsed time 41.21
# [IterativeImputer] Ending imputation round 28/50, elapsed time 43.38
# [IterativeImputer] Ending imputation round 29/50, elapsed time 45.54
# [IterativeImputer] Ending imputation round 30/50, elapsed time 47.25
# [IterativeImputer] Ending imputation round 31/50, elapsed time 48.77
# [IterativeImputer] Ending imputation round 32/50, elapsed time 50.27
# [IterativeImputer] Ending imputation round 33/50, elapsed time 51.76
# [IterativeImputer] Ending imputation round 34/50, elapsed time 53.36
# [IterativeImputer] Ending imputation round 35/50, elapsed time 55.05
# [IterativeImputer] Ending imputation round 36/50, elapsed time 56.59
# [IterativeImputer] Ending imputation round 37/50, elapsed time 58.09
# [IterativeImputer] Ending imputation round 38/50, elapsed time 59.70
# [IterativeImputer] Ending imputation round 39/50, elapsed time 61.18
# [IterativeImputer] Ending imputation round 40/50, elapsed time 62.77
# [IterativeImputer] Ending imputation round 41/50, elapsed time 64.24
# [IterativeImputer] Ending imputation round 42/50, elapsed time 65.75
# [IterativeImputer] Ending imputation round 43/50, elapsed time 67.22
# [IterativeImputer] Ending imputation round 44/50, elapsed time 68.70
# [IterativeImputer] Ending imputation round 45/50, elapsed time 70.16
# [IterativeImputer] Ending imputation round 46/50, elapsed time 71.66
# [IterativeImputer] Ending imputation round 47/50, elapsed time 73.13
# [IterativeImputer] Ending imputation round 48/50, elapsed time 74.61
# [IterativeImputer] Ending imputation round 49/50, elapsed time 76.21
# [IterativeImputer] Ending imputation round 50/50, elapsed time 77.70
# CatBoost imputation predictions saved to 'catboost_predictions.csv'.
