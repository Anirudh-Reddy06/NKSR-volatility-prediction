# %%
import pandas as pd
import numpy as np
from sklearn.experimental import enable_iterative_imputer  # noqa: F401
from sklearn.impute import IterativeImputer
from sklearn.ensemble import HistGradientBoostingRegressor
import warnings
warnings.filterwarnings('ignore')

# Load your data
test = pd.read_parquet('test_data.parquet')
sample_submission = pd.read_csv('sample_submission.csv')

# Identify target columns (excluding 'timestamp')
target_columns = [col for col in sample_submission.columns if col != 'timestamp']
submission = sample_submission.copy()
for col in target_columns:
    submission[col] = test[col] if col in test.columns else np.nan

# Optionally include 'underlying' if present
if 'underlying' in test.columns:
    submission['underlying'] = test['underlying']
    all_imputation_cols = target_columns + ['underlying']
else:
    all_imputation_cols = target_columns

# Setup HistGradientBoostingRegressor imputer
imputer_hist = IterativeImputer(
    estimator=HistGradientBoostingRegressor(
        max_iter=400,
        max_depth=15,
        learning_rate=0.1,
        early_stopping=True,
        random_state=42
    ),
    max_iter=60,
    tol=1e-6,
    n_nearest_features=20,
    initial_strategy='median',
    imputation_order='ascending',
    random_state=42,
    verbose=2
)

# Fit imputer on the submission data
imputer_hist.fit(submission[all_imputation_cols])

# Transform to get imputed values
imputed_hist = imputer_hist.transform(submission[all_imputation_cols])

# Prepare output dataframe
hist_pred = submission.copy()
hist_pred[target_columns] = imputed_hist[:, :len(target_columns)]

# Save to CSV for blending or submission
hist_pred.to_csv('hist_imputation.csv', index=False)
print("HistGradientBoosting imputation predictions saved to 'hist_predictions.csv'.")
# Out:
# [IterativeImputer] Completing matrix with shape (12065, 53)
# [IterativeImputer] Ending imputation round 1/60, elapsed time 17.98
# [IterativeImputer] Change: 2.566810101181985, scaled tolerance: 0.0250595
# [IterativeImputer] Ending imputation round 2/60, elapsed time 65.06
# [IterativeImputer] Change: 0.40203123905179317, scaled tolerance: 0.0250595
# [IterativeImputer] Ending imputation round 3/60, elapsed time 80.56
# [IterativeImputer] Change: 0.269999974059586, scaled tolerance: 0.0250595
# [IterativeImputer] Ending imputation round 4/60, elapsed time 94.28
# [IterativeImputer] Change: 0.18683017737714053, scaled tolerance: 0.0250595
# [IterativeImputer] Ending imputation round 5/60, elapsed time 107.68
# [IterativeImputer] Change: 0.19485893017038405, scaled tolerance: 0.0250595
# [IterativeImputer] Ending imputation round 6/60, elapsed time 121.15
# [IterativeImputer] Change: 0.15579405499343404, scaled tolerance: 0.0250595
# [IterativeImputer] Ending imputation round 7/60, elapsed time 135.75
# [IterativeImputer] Change: 0.16903791078676134, scaled tolerance: 0.0250595
# [IterativeImputer] Ending imputation round 8/60, elapsed time 238.22
# [IterativeImputer] Change: 0.13076775963105372, scaled tolerance: 0.0250595
# [IterativeImputer] Ending imputation round 9/60, elapsed time 335.86
# [IterativeImputer] Change: 0.13723060309940818, scaled tolerance: 0.0250595
# [IterativeImputer] Ending imputation round 10/60, elapsed time 367.39
# [IterativeImputer] Change: 0.18256145014081845, scaled tolerance: 0.0250595
# [IterativeImputer] Ending imputation round 11/60, elapsed time 380.89
# [IterativeImputer] Change: 0.13622042372831494, scaled tolerance: 0.0250595
# [IterativeImputer] Ending imputation round 12/60, elapsed time 394.76
# [IterativeImputer] Change: 0.1758041854006908, scaled tolerance: 0.0250595
# [IterativeImputer] Ending imputation round 13/60, elapsed time 408.28
# [IterativeImputer] Change: 0.19813212471569908, scaled tolerance: 0.0250595
# [IterativeImputer] Ending imputation round 14/60, elapsed time 442.12
# [IterativeImputer] Change: 0.16340028413390434, scaled tolerance: 0.0250595
# [IterativeImputer] Ending imputation round 15/60, elapsed time 522.28
# [IterativeImputer] Change: 0.13722066621060175, scaled tolerance: 0.0250595
# [IterativeImputer] Ending imputation round 16/60, elapsed time 597.77
# [IterativeImputer] Change: 0.09233085759740883, scaled tolerance: 0.0250595
# [IterativeImputer] Ending imputation round 17/60, elapsed time 653.20
# [IterativeImputer] Change: 0.1514001629367133, scaled tolerance: 0.0250595
# [IterativeImputer] Ending imputation round 18/60, elapsed time 667.13
# [IterativeImputer] Change: 0.24760603729622077, scaled tolerance: 0.0250595
# [IterativeImputer] Ending imputation round 19/60, elapsed time 680.21
# [IterativeImputer] Change: 0.19001395811931926, scaled tolerance: 0.0250595
# [IterativeImputer] Ending imputation round 20/60, elapsed time 694.24
# [IterativeImputer] Change: 0.15616637934325803, scaled tolerance: 0.0250595
# [IterativeImputer] Ending imputation round 21/60, elapsed time 708.09
# [IterativeImputer] Change: 0.16183880939409495, scaled tolerance: 0.0250595
# [IterativeImputer] Ending imputation round 22/60, elapsed time 721.45
# [IterativeImputer] Change: 0.11695549667078212, scaled tolerance: 0.0250595
# [IterativeImputer] Ending imputation round 23/60, elapsed time 735.05
# [IterativeImputer] Change: 0.16659547526448787, scaled tolerance: 0.0250595
# [IterativeImputer] Ending imputation round 24/60, elapsed time 749.05
# [IterativeImputer] Change: 0.11592489539944706, scaled tolerance: 0.0250595
# [IterativeImputer] Ending imputation round 25/60, elapsed time 763.61
# [IterativeImputer] Change: 0.19854585636959396, scaled tolerance: 0.0250595
# [IterativeImputer] Ending imputation round 26/60, elapsed time 777.70
# [IterativeImputer] Change: 0.15586619493212506, scaled tolerance: 0.0250595
# [IterativeImputer] Ending imputation round 27/60, elapsed time 792.12
# [IterativeImputer] Change: 0.17099127032803207, scaled tolerance: 0.0250595
# [IterativeImputer] Ending imputation round 28/60, elapsed time 805.75
# [IterativeImputer] Change: 0.15943885772004934, scaled tolerance: 0.0250595
# [IterativeImputer] Ending imputation round 29/60, elapsed time 820.35
# [IterativeImputer] Change: 0.14716886557742065, scaled tolerance: 0.0250595
# [IterativeImputer] Ending imputation round 30/60, elapsed time 833.32
# [IterativeImputer] Change: 0.16785494856131297, scaled tolerance: 0.0250595
# [IterativeImputer] Ending imputation round 31/60, elapsed time 847.27
# [IterativeImputer] Change: 0.15584037880312454, scaled tolerance: 0.0250595
# [IterativeImputer] Ending imputation round 32/60, elapsed time 860.87
# [IterativeImputer] Change: 0.11455264507993909, scaled tolerance: 0.0250595
# [IterativeImputer] Ending imputation round 33/60, elapsed time 874.60
# [IterativeImputer] Change: 0.14027931640134247, scaled tolerance: 0.0250595
# [IterativeImputer] Ending imputation round 34/60, elapsed time 890.67
# [IterativeImputer] Change: 0.19617957339878547, scaled tolerance: 0.0250595
# [IterativeImputer] Ending imputation round 35/60, elapsed time 912.70
# [IterativeImputer] Change: 0.20497273618160314, scaled tolerance: 0.0250595
# [IterativeImputer] Ending imputation round 36/60, elapsed time 935.10
# [IterativeImputer] Change: 0.11909975149914748, scaled tolerance: 0.0250595
# [IterativeImputer] Ending imputation round 37/60, elapsed time 957.64
# [IterativeImputer] Change: 0.16463145162650658, scaled tolerance: 0.0250595
# [IterativeImputer] Ending imputation round 38/60, elapsed time 980.36
# [IterativeImputer] Change: 0.1790096578286984, scaled tolerance: 0.0250595
# [IterativeImputer] Ending imputation round 39/60, elapsed time 1003.10
# [IterativeImputer] Change: 0.216787273293745, scaled tolerance: 0.0250595
# [IterativeImputer] Ending imputation round 40/60, elapsed time 1025.91
# [IterativeImputer] Change: 0.15317511126689828, scaled tolerance: 0.0250595
# [IterativeImputer] Ending imputation round 41/60, elapsed time 1048.69
# [IterativeImputer] Change: 0.15948904854367707, scaled tolerance: 0.0250595
# [IterativeImputer] Ending imputation round 42/60, elapsed time 1070.92
# [IterativeImputer] Change: 0.11827827352324188, scaled tolerance: 0.0250595
# [IterativeImputer] Ending imputation round 43/60, elapsed time 1094.01
# [IterativeImputer] Change: 0.17291961450251025, scaled tolerance: 0.0250595
# [IterativeImputer] Ending imputation round 44/60, elapsed time 1116.18
# [IterativeImputer] Change: 0.11404072073785873, scaled tolerance: 0.0250595
# [IterativeImputer] Ending imputation round 45/60, elapsed time 1138.87
# [IterativeImputer] Change: 0.1448332881508332, scaled tolerance: 0.0250595
# [IterativeImputer] Ending imputation round 46/60, elapsed time 1162.32
# [IterativeImputer] Change: 0.13820579770326982, scaled tolerance: 0.0250595
# [IterativeImputer] Ending imputation round 47/60, elapsed time 1184.98
# [IterativeImputer] Change: 0.11913250447769588, scaled tolerance: 0.0250595
# [IterativeImputer] Ending imputation round 48/60, elapsed time 1206.97
# [IterativeImputer] Change: 0.09975325606423843, scaled tolerance: 0.0250595
# [IterativeImputer] Ending imputation round 49/60, elapsed time 1229.87
# [IterativeImputer] Change: 0.12908438053398322, scaled tolerance: 0.0250595
# [IterativeImputer] Ending imputation round 50/60, elapsed time 1251.61
# [IterativeImputer] Change: 0.137771056285137, scaled tolerance: 0.0250595
# [IterativeImputer] Ending imputation round 51/60, elapsed time 1275.60
# [IterativeImputer] Change: 0.11839721506507447, scaled tolerance: 0.0250595
# [IterativeImputer] Ending imputation round 52/60, elapsed time 1300.28
# [IterativeImputer] Change: 0.18154136607766277, scaled tolerance: 0.0250595
# [IterativeImputer] Ending imputation round 53/60, elapsed time 1324.51
# [IterativeImputer] Change: 0.13467197448645257, scaled tolerance: 0.0250595
# [IterativeImputer] Ending imputation round 54/60, elapsed time 1348.21
# [IterativeImputer] Change: 0.08169640480197352, scaled tolerance: 0.0250595
# [IterativeImputer] Ending imputation round 55/60, elapsed time 1372.51
# [IterativeImputer] Change: 0.10375358935755483, scaled tolerance: 0.0250595
# [IterativeImputer] Ending imputation round 56/60, elapsed time 1396.88
# [IterativeImputer] Change: 0.13435839448034786, scaled tolerance: 0.0250595
# [IterativeImputer] Ending imputation round 57/60, elapsed time 1420.08
# [IterativeImputer] Change: 0.14346717780228063, scaled tolerance: 0.0250595
# [IterativeImputer] Ending imputation round 58/60, elapsed time 1445.43
# [IterativeImputer] Change: 0.1331706670455567, scaled tolerance: 0.0250595
# [IterativeImputer] Ending imputation round 59/60, elapsed time 1469.91
# [IterativeImputer] Change: 0.12734610375538133, scaled tolerance: 0.0250595
# [IterativeImputer] Ending imputation round 60/60, elapsed time 1493.34
# [IterativeImputer] Change: 0.07123721194519209, scaled tolerance: 0.0250595
# [IterativeImputer] Completing matrix with shape (12065, 53)
# [IterativeImputer] Ending imputation round 1/60, elapsed time 1.04
# [IterativeImputer] Ending imputation round 2/60, elapsed time 1.91
# [IterativeImputer] Ending imputation round 3/60, elapsed time 2.85
# [IterativeImputer] Ending imputation round 4/60, elapsed time 3.68
# [IterativeImputer] Ending imputation round 5/60, elapsed time 4.57
# [IterativeImputer] Ending imputation round 6/60, elapsed time 5.49
# [IterativeImputer] Ending imputation round 7/60, elapsed time 6.36
# [IterativeImputer] Ending imputation round 8/60, elapsed time 7.26
# [IterativeImputer] Ending imputation round 9/60, elapsed time 8.15
# [IterativeImputer] Ending imputation round 10/60, elapsed time 9.09
# [IterativeImputer] Ending imputation round 11/60, elapsed time 10.00
# [IterativeImputer] Ending imputation round 12/60, elapsed time 10.87
# [IterativeImputer] Ending imputation round 13/60, elapsed time 11.72
# [IterativeImputer] Ending imputation round 14/60, elapsed time 12.60
# [IterativeImputer] Ending imputation round 15/60, elapsed time 13.54
# [IterativeImputer] Ending imputation round 16/60, elapsed time 14.43
# [IterativeImputer] Ending imputation round 17/60, elapsed time 15.31
# [IterativeImputer] Ending imputation round 18/60, elapsed time 16.21
# [IterativeImputer] Ending imputation round 19/60, elapsed time 17.15
# [IterativeImputer] Ending imputation round 20/60, elapsed time 18.05
# [IterativeImputer] Ending imputation round 21/60, elapsed time 18.93
# [IterativeImputer] Ending imputation round 22/60, elapsed time 19.83
# [IterativeImputer] Ending imputation round 23/60, elapsed time 20.68
# [IterativeImputer] Ending imputation round 24/60, elapsed time 21.55
# [IterativeImputer] Ending imputation round 25/60, elapsed time 22.49
# [IterativeImputer] Ending imputation round 26/60, elapsed time 23.40
# [IterativeImputer] Ending imputation round 27/60, elapsed time 24.30
# [IterativeImputer] Ending imputation round 28/60, elapsed time 25.18
# [IterativeImputer] Ending imputation round 29/60, elapsed time 26.08
# [IterativeImputer] Ending imputation round 30/60, elapsed time 26.99
# [IterativeImputer] Ending imputation round 31/60, elapsed time 28.01
# [IterativeImputer] Ending imputation round 32/60, elapsed time 28.92
# [IterativeImputer] Ending imputation round 33/60, elapsed time 29.80
# [IterativeImputer] Ending imputation round 34/60, elapsed time 30.70
# [IterativeImputer] Ending imputation round 35/60, elapsed time 31.60
# [IterativeImputer] Ending imputation round 36/60, elapsed time 32.49
# [IterativeImputer] Ending imputation round 37/60, elapsed time 33.39
# [IterativeImputer] Ending imputation round 38/60, elapsed time 34.29
# [IterativeImputer] Ending imputation round 39/60, elapsed time 35.19
# [IterativeImputer] Ending imputation round 40/60, elapsed time 36.07
# [IterativeImputer] Ending imputation round 41/60, elapsed time 36.93
# [IterativeImputer] Ending imputation round 42/60, elapsed time 37.79
# [IterativeImputer] Ending imputation round 43/60, elapsed time 38.65
# [IterativeImputer] Ending imputation round 44/60, elapsed time 39.51
# [IterativeImputer] Ending imputation round 45/60, elapsed time 40.38
# [IterativeImputer] Ending imputation round 46/60, elapsed time 41.25
# [IterativeImputer] Ending imputation round 47/60, elapsed time 42.13
# [IterativeImputer] Ending imputation round 48/60, elapsed time 43.06
# [IterativeImputer] Ending imputation round 49/60, elapsed time 43.99
# [IterativeImputer] Ending imputation round 50/60, elapsed time 44.92
# [IterativeImputer] Ending imputation round 51/60, elapsed time 45.78
# [IterativeImputer] Ending imputation round 52/60, elapsed time 46.64
# [IterativeImputer] Ending imputation round 53/60, elapsed time 47.50
# [IterativeImputer] Ending imputation round 54/60, elapsed time 48.38
# [IterativeImputer] Ending imputation round 55/60, elapsed time 49.30
# [IterativeImputer] Ending imputation round 56/60, elapsed time 50.18
# [IterativeImputer] Ending imputation round 57/60, elapsed time 51.05
# [IterativeImputer] Ending imputation round 58/60, elapsed time 51.93
# [IterativeImputer] Ending imputation round 59/60, elapsed time 52.85
# [IterativeImputer] Ending imputation round 60/60, elapsed time 53.76
# HistGradientBoosting imputation predictions saved to 'hist_predictions.csv'.
